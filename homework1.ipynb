# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('food-allergy-analysis-Zenodo.csv')

# %%
data
# Out:
#         SUBJECT_ID  BIRTH_YEAR GENDER_FACTOR   RACE_FACTOR   ETHNICITY_FACTOR  \
# 0                1        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 1                2        1994   S1 - Female    R0 - White  E0 - Non-Hispanic
# 2                3        2006     S0 - Male    R0 - White      E1 - Hispanic
# 3                4        2004     S0 - Male  R4 - Unknown      E1 - Hispanic
# 4                5        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# ...            ...         ...           ...           ...                ...
# 333195      333196        2006     S0 - Male    R0 - White  E0 - Non-Hispanic
# 333196      333197        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 333197      333198        2006     S0 - Male    R0 - White  E0 - Non-Hispanic
# 333198      333199        2006     S0 - Male    R3 - Other  E0 - Non-Hispanic
# 333199      333200        2006   S1 - Female    R0 - White  E0 - Non-Hispanic
#
# ...

# %%
data.iloc[0]['SUBJECT_ID']
# Out:
# 1

# %%
data.isnull().sum()
# Out:
# SUBJECT_ID                      0
# BIRTH_YEAR                      0
# GENDER_FACTOR                   0
# RACE_FACTOR                     0
# ETHNICITY_FACTOR                0
# PAYER_FACTOR                    0
# ATOPIC_MARCH_COHORT             0
# AGE_START_YEARS                 0
# AGE_END_YEARS                   0
# SHELLFISH_ALG_START        327954
# SHELLFISH_ALG_END          332149
# FISH_ALG_START             331404
# FISH_ALG_END               332673
# MILK_ALG_START             325911
# MILK_ALG_END               328620
# SOY_ALG_START              330781
# SOY_ALG_END                331769
# EGG_ALG_START              327135
# EGG_ALG_END                329907
# WHEAT_ALG_START            332054
# WHEAT_ALG_END              332512
# PEANUT_ALG_START           324547
# PEANUT_ALG_END             331108
# SESAME_ALG_START           332434
# SESAME_ALG_END             333022
# TREENUT_ALG_START          333199
# TREENUT_ALG_END            333200
# ...

# %%
data.shape
# Out:
# (333200, 50)

# %%
data.columns
# Out:
# Index(['SUBJECT_ID', 'BIRTH_YEAR', 'GENDER_FACTOR', 'RACE_FACTOR',
#        'ETHNICITY_FACTOR', 'PAYER_FACTOR', 'ATOPIC_MARCH_COHORT',
#        'AGE_START_YEARS', 'AGE_END_YEARS', 'SHELLFISH_ALG_START',
#        'SHELLFISH_ALG_END', 'FISH_ALG_START', 'FISH_ALG_END', 'MILK_ALG_START',
#        'MILK_ALG_END', 'SOY_ALG_START', 'SOY_ALG_END', 'EGG_ALG_START',
#        'EGG_ALG_END', 'WHEAT_ALG_START', 'WHEAT_ALG_END', 'PEANUT_ALG_START',
#        'PEANUT_ALG_END', 'SESAME_ALG_START', 'SESAME_ALG_END',
#        'TREENUT_ALG_START', 'TREENUT_ALG_END', 'WALNUT_ALG_START',
#        'WALNUT_ALG_END', 'PECAN_ALG_START', 'PECAN_ALG_END',
#        'PISTACH_ALG_START', 'PISTACH_ALG_END', 'ALMOND_ALG_START',
#        'ALMOND_ALG_END', 'BRAZIL_ALG_START', 'BRAZIL_ALG_END',
#        'HAZELNUT_ALG_START', 'HAZELNUT_ALG_END', 'CASHEW_ALG_START',
#        'CASHEW_ALG_END', 'ATOPIC_DERM_START', 'ATOPIC_DERM_END',
#        'ALLERGIC_RHINITIS_START', 'ALLERGIC_RHINITIS_END', 'ASTHMA_START',
# ...

# %% [markdown]
# # GENDER_FACTOR

# %%
data['GENDER_FACTOR'].value_counts()
# Out:
# S0 - Male      169032
# S1 - Female    164168
# Name: GENDER_FACTOR, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
 
# Creating a instance of label Encoder.
le = LabelEncoder()
 
# Using .fit_transform function to fit label
# encoder and return encoded label
label = le.fit_transform(data['GENDER_FACTOR'])
 
# printing label
label
# Out:
# array([1, 1, 0, ..., 0, 0, 1])

# %%
data.drop('GENDER_FACTOR', axis=1, inplace=True)
 
# Appending the array to our dataFrame
# with column name 'Purchased'
data['GENDER_FACTOR'] = label
 
# printing Dataframe
data
# Out:
#         SUBJECT_ID  BIRTH_YEAR   RACE_FACTOR   ETHNICITY_FACTOR  \
# 0                1        2006    R1 - Black  E0 - Non-Hispanic
# 1                2        1994    R0 - White  E0 - Non-Hispanic
# 2                3        2006    R0 - White      E1 - Hispanic
# 3                4        2004  R4 - Unknown      E1 - Hispanic
# 4                5        2006    R1 - Black  E0 - Non-Hispanic
# ...            ...         ...           ...                ...
# 333195      333196        2006    R0 - White  E0 - Non-Hispanic
# 333196      333197        2006    R1 - Black  E0 - Non-Hispanic
# 333197      333198        2006    R0 - White  E0 - Non-Hispanic
# 333198      333199        2006    R3 - Other  E0 - Non-Hispanic
# 333199      333200        2006    R0 - White  E0 - Non-Hispanic
#
#              PAYER_FACTOR  ATOPIC_MARCH_COHORT  AGE_START_YEARS  \
# 0           P1 - Medicaid                False         0.093087
# 1       P0 - Non-Medicaid                False        12.232717
# ...

# %% [markdown]
# # RACE_FACTOR

# %%
data['RACE_FACTOR'].value_counts()
# Out:
# R0 - White                        183308
# R1 - Black                         97795
# R4 - Unknown                       40940
# R2 - Asian or Pacific Islander      9152
# R3 - Other                          2005
# Name: RACE_FACTOR, dtype: int64

# %%
label = le.fit_transform(data['RACE_FACTOR'])
 
# printing label
label
data.drop('RACE_FACTOR', axis=1, inplace=True)
 
# Appending the array to our dataFrame
# with column name 'Purchased'
data['RACE_FACTOR'] = label
 
# printing Dataframe
data
# Out:
#         SUBJECT_ID  BIRTH_YEAR   ETHNICITY_FACTOR       PAYER_FACTOR  \
# 0                1        2006  E0 - Non-Hispanic      P1 - Medicaid
# 1                2        1994  E0 - Non-Hispanic  P0 - Non-Medicaid
# 2                3        2006      E1 - Hispanic  P0 - Non-Medicaid
# 3                4        2004      E1 - Hispanic  P0 - Non-Medicaid
# 4                5        2006  E0 - Non-Hispanic  P0 - Non-Medicaid
# ...            ...         ...                ...                ...
# 333195      333196        2006  E0 - Non-Hispanic  P0 - Non-Medicaid
# 333196      333197        2006  E0 - Non-Hispanic      P1 - Medicaid
# 333197      333198        2006  E0 - Non-Hispanic  P0 - Non-Medicaid
# 333198      333199        2006  E0 - Non-Hispanic  P0 - Non-Medicaid
# 333199      333200        2006  E0 - Non-Hispanic  P0 - Non-Medicaid
#
#         ATOPIC_MARCH_COHORT  AGE_START_YEARS  AGE_END_YEARS  \
# 0                     False         0.093087       3.164956
# ...

# %% [markdown]
# # ETHNICITY_FACTOR

# %%
data['ETHNICITY_FACTOR'].value_counts()
# Out:
# E0 - Non-Hispanic    317868
# E1 - Hispanic         15332
# Name: ETHNICITY_FACTOR, dtype: int64

# %%
label = le.fit_transform(data['ETHNICITY_FACTOR'])
 
# printing label
label
data.drop('ETHNICITY_FACTOR', axis=1, inplace=True)
 
# Appending the array to our dataFrame
# with column name 'Purchased'
data['ETHNICITY_FACTOR'] = label
 
# printing Dataframe
data
# Out:
#         SUBJECT_ID  BIRTH_YEAR       PAYER_FACTOR  ATOPIC_MARCH_COHORT  \
# 0                1        2006      P1 - Medicaid                False
# 1                2        1994  P0 - Non-Medicaid                False
# 2                3        2006  P0 - Non-Medicaid                 True
# 3                4        2004  P0 - Non-Medicaid                False
# 4                5        2006  P0 - Non-Medicaid                False
# ...            ...         ...                ...                  ...
# 333195      333196        2006  P0 - Non-Medicaid                False
# 333196      333197        2006      P1 - Medicaid                 True
# 333197      333198        2006  P0 - Non-Medicaid                False
# 333198      333199        2006  P0 - Non-Medicaid                 True
# 333199      333200        2006  P0 - Non-Medicaid                False
#
#         AGE_START_YEARS  AGE_END_YEARS  SHELLFISH_ALG_START  \
# ...

# %% [markdown]
# # PAYER_FACTOR

# %%
data['PAYER_FACTOR'].value_counts()
# Out:
# P0 - Non-Medicaid    246340
# P1 - Medicaid         86860
# Name: PAYER_FACTOR, dtype: int64

# %%
label = le.fit_transform(data['PAYER_FACTOR'])
 
# printing label
label
data.drop('PAYER_FACTOR', axis=1, inplace=True)
 
# Appending the array to our dataFrame
# with column name 'Purchased'
data['PAYER_FACTOR'] = label
 
# printing Dataframe
data
# Out:
#         SUBJECT_ID  BIRTH_YEAR  ATOPIC_MARCH_COHORT  AGE_START_YEARS  \
# 0                1        2006                False         0.093087
# 1                2        1994                False        12.232717
# 2                3        2006                 True         0.010951
# 3                4        2004                False         2.398357
# 4                5        2006                False         0.013689
# ...            ...         ...                  ...              ...
# 333195      333196        2006                False         0.736482
# 333196      333197        2006                 True         0.019165
# 333197      333198        2006                False         0.443532
# 333198      333199        2006                 True         0.013689
# 333199      333200        2006                False         0.019165
#
#         AGE_END_YEARS  SHELLFISH_ALG_START  SHELLFISH_ALG_END  FISH_ALG_START  \
# ...

# %% [markdown]
# # change the order of the columns

# %%
column_names =['SUBJECT_ID', 'BIRTH_YEAR', 'GENDER_FACTOR', 'RACE_FACTOR',
       'ETHNICITY_FACTOR', 'PAYER_FACTOR', 'ATOPIC_MARCH_COHORT',
       'AGE_START_YEARS', 'AGE_END_YEARS', 'SHELLFISH_ALG_START',
       'SHELLFISH_ALG_END', 'FISH_ALG_START', 'FISH_ALG_END', 'MILK_ALG_START',
       'MILK_ALG_END', 'SOY_ALG_START', 'SOY_ALG_END', 'EGG_ALG_START',
       'EGG_ALG_END', 'WHEAT_ALG_START', 'WHEAT_ALG_END', 'PEANUT_ALG_START',
       'PEANUT_ALG_END', 'SESAME_ALG_START', 'SESAME_ALG_END',
       'TREENUT_ALG_START', 'TREENUT_ALG_END', 'WALNUT_ALG_START',
       'WALNUT_ALG_END', 'PECAN_ALG_START', 'PECAN_ALG_END',
       'PISTACH_ALG_START', 'PISTACH_ALG_END', 'ALMOND_ALG_START',
       'ALMOND_ALG_END', 'BRAZIL_ALG_START', 'BRAZIL_ALG_END',
       'HAZELNUT_ALG_START', 'HAZELNUT_ALG_END', 'CASHEW_ALG_START',
       'CASHEW_ALG_END', 'ATOPIC_DERM_START', 'ATOPIC_DERM_END',
       'ALLERGIC_RHINITIS_START', 'ALLERGIC_RHINITIS_END', 'ASTHMA_START',
       'ASTHMA_END', 'FIRST_ASTHMARX', 'LAST_ASTHMARX', 'NUM_ASTHMARX']

data = data.reindex(columns=column_names)

# %%
data
# Out:
#         SUBJECT_ID  BIRTH_YEAR  GENDER_FACTOR  RACE_FACTOR  ETHNICITY_FACTOR  \
# 0                1        2006              1            1                 0
# 1                2        1994              1            0                 0
# 2                3        2006              0            0                 1
# 3                4        2004              0            4                 1
# 4                5        2006              1            1                 0
# ...            ...         ...            ...          ...               ...
# 333195      333196        2006              0            0                 0
# 333196      333197        2006              1            1                 0
# 333197      333198        2006              0            0                 0
# 333198      333199        2006              0            3                 0
# 333199      333200        2006              1            0                 0
#
# ...

# %% [markdown]
# #

# %% [markdown]
# # add the y column

# %%
# I removed the age start and age end because it's not related to allergies
a = data.iloc[:,9:50]

# %%
print(a)
# Out:
#         SHELLFISH_ALG_START  SHELLFISH_ALG_END  FISH_ALG_START  FISH_ALG_END  \
# 0                       NaN                NaN             NaN           NaN
# 1                       NaN                NaN             NaN           NaN
# 2                       NaN                NaN             NaN           NaN
# 3                       NaN                NaN             NaN           NaN
# 4                       NaN                NaN             NaN           NaN
# ...                     ...                ...             ...           ...
# 333195                  NaN                NaN             NaN           NaN
# 333196                  NaN                NaN             NaN           NaN
# 333197                  NaN                NaN             NaN           NaN
# 333198                  NaN                NaN             NaN           NaN
# 333199                  NaN                NaN             NaN           NaN
#
# ...

# %%
# Replace NaN with 0
a.replace(to_replace = np.nan, value =0)
# any() method to checks whether any value in each row is not 0 and returns True
data["has_allergy"] = a.any(axis = 1)
# Replace boolean into int (0 or 1)
data["has_allergy"] = data["has_allergy"].astype(int)

# %%
data["has_allergy"].value_counts()
# Out:
# 1    167867
# 0    165333
# Name: has_allergy, dtype: int64

# %%
y=data["has_allergy"]

# %%
#for col in a:
   # if pd.isna(data[col]) :
 #       y= False
  #  else: 
    #    y=True

# %%
#for col in a:
 #   if data[col].notna():
  #      y=0
   # else:
    #    y=1

# %% [markdown]
# # the x columns

# %%
x = data.iloc[:,1:5]

# %%
print(x)
# Out:
#         BIRTH_YEAR  GENDER_FACTOR  RACE_FACTOR  ETHNICITY_FACTOR
# 0             2006              1            1                 0
# 1             1994              1            0                 0
# 2             2006              0            0                 1
# 3             2004              0            4                 1
# 4             2006              1            1                 0
# ...            ...            ...          ...               ...
# 333195        2006              0            0                 0
# 333196        2006              1            1                 0
# 333197        2006              0            0                 0
# 333198        2006              0            3                 0
# 333199        2006              1            0                 0
#
# [333200 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # logistic regression

# %%
class logistic_regression():
    def __init__(self,learning_rate,iterations):
        self.learning_rate=learning_rate
        self.iterations=iterations
    def fit(self,X,Y):
        self.m,self.n=X.shape
        self.W=np.zeros(self.n)
        self.b=0
        self.X=X
        self.Y=Y
        
        for i in range (self.iterations):
            self.update_weights()
        return self
    def update_weights(self):
        A = 1/(1+np.exp(-(self.X.dot(self.W)+self.b)))
        tmp = (A-self.Y.T)
        tmp = np.reshape(tmp,self.m)
        dW = np.dot(self.X.T,tmp)/self.m
        db = np.sum(tmp)/self.m
        
        self.W = self.W-self.learning_rate*dW
        self.b = self.b-self.learning_rate*db
        
        return self
    def predict(self,X):
        Z = 1/(1+np.exp(-(X.dot(self.W)+self.b)))
        Y = np.where(Z>0.5,1,0)
        return Y

# %%
def get_accuracy(y_pred,Y_test):
    correctly_classified = 0
    # Changed here, because Y_pred is of type pandas.core.Series
    for i, elem in enumerate (Y_pred):
        if elem ==y_pred[i]:
            correctly_classified=correctly_classified+1
        acc = (correctly_classified/len(Y_pred))*100
    return acc

# %%
model = logistic_regression(learning_rate=0.01,iterations=1000)
model.fit(X_train,Y_train)
Y_pred=model.predict(X_test)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from sklearn.linear_model import LogisticRegression
sk_model = LogisticRegression(max_iter=200)

# %%
sk_model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
y_pred2 = sk_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_pred,Y_test)
# Out:
# 0.4976590636254502

# %%
y_pred2
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
acc2 = get_accuracy(y_pred2,Y_test)

# %%
acc2
# Out:
# 0.0
